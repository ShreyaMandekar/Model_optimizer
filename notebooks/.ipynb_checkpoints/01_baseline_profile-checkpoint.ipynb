# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.insert(0, "/home/shreya/fusion_aware_qat")

import torch
import os

print(f"PyTorch:  {torch.__version__}")
print(f"CUDA:     {torch.cuda.is_available()}")
print(f"GPU:      {torch.cuda.get_device_name(0)}")
print(f"VRAM:     {torch.cuda.get_device_properties(0).total_memory / 1e9:.1f} GB")
# Out:
# PyTorch:  2.5.1+cu121
# CUDA:     True
# GPU:      NVIDIA GeForce RTX 4060 Laptop GPU
# VRAM:     8.2 GB

# %%
import transformers
print(transformers.__version__)
# Out:
# 5.3.0

# %%
BATCH_SIZE = 4
SEQ_LEN    = 64
MODEL_NAME = "prajjwal1/bert-tiny"
DEVICE     = "cuda"
SAVE_DIR   = "/home/shreya/fusion_aware_qat/results"
BATCH_SIZE = 4
SEQ_LEN    = 64
MODEL_NAME = "google/bert_uncased_L-2_H-128_A-2"   # ← changed
DEVICE     = "cuda"
SAVE_DIR   = "/home/shreya/fusion_aware_qat/results"

print(f"Batch:   {BATCH_SIZE} x {SEQ_LEN}")
print(f"Model:   {MODEL_NAME}")
print(f"Device:  {DEVICE}")
print(f"Batch:   {BATCH_SIZE} x {SEQ_LEN}")
print(f"Device:  {DEVICE}")
print(f"Saving:  {SAVE_DIR}")

# %%
from transformers import AutoModelForSequenceClassification

fp32_model = AutoModelForSequenceClassification.from_pretrained(
    MODEL_NAME,
    num_labels=2,
    ignore_mismatched_sizes=True
).to(DEVICE).eval()

print(f"Parameters: {sum(p.numel() for p in fp32_model.parameters()):,}")
print("FP32 model loaded ✓")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 3
#       1 from transformers import AutoModelForSequenceClassification
# ----> 3 fp32_model = AutoModelForSequenceClassification.from_pretrained(
#       4     MODEL_NAME,
#       5     num_labels=2,
#       6     ignore_mismatched_sizes=True
#       7 ).to(DEVICE).eval()
#       9 print(f"Parameters: {sum(p.numel() for p in fp32_model.parameters()):,}")
#      10 print("FP32 model loaded ✓")
#
# File ~/venvs/fusion_qat/lib/python3.12/site-packages/transformers/models/auto/auto_factory.py:319, in _BaseAutoModelClass.from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     316 if kwargs.get("quantization_config") is not None:
#     317     _ = kwargs.pop("quantization_config")
# --> 319 config, kwargs = AutoConfig.from_pretrained(
#     320     pretrained_model_name_or_path,
#     321     return_unused_kwargs=True,
#     322     code_revision=code_revision,
#     323     _commit_hash=commit_hash,
#     324     **hub_kwargs,
#     325     **kwargs,
#     326 )
#     328 # if torch_dtype=auto was passed here, ensure to pass it on
#     329 if kwargs_orig.get("torch_dtype", None) == "auto":
#
# File ~/venvs/fusion_qat/lib/python3.12/site-packages/transformers/models/auto/configuration_auto.py:1471, in AutoConfig.from_pretrained(cls, pretrained_model_name_or_path, **kwargs)
#    1459         raise ValueError(
#    1460             f"The checkpoint you are trying to load has model type `{config_dict['model_type']}` "
#    1461             "but Transformers does not recognize this architecture. This could be because of an "
#    (...)   1467             "`pip install git+https://github.com/huggingface/transformers.git`"
#    1468         )
#    1469     return config_class.from_dict(config_dict, **unused_kwargs)
# -> 1471 raise ValueError(
#    1472     f"Unrecognized model in {pretrained_model_name_or_path}. "
#    1473     f"Should have a `model_type` key in its {CONFIG_NAME}."
#    1474 )
#
# ValueError: Unrecognized model in prajjwal1/bert-tiny. Should have a `model_type` key in its config.json.
