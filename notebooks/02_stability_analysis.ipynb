# %%
# !which python
# Out:
# /home/shreya/venvs/jupyter/bin/python

# %%
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 6
#       3 import sys
#       4 sys.path.insert(0, '/home/shreya/Coding/optimizer_V2')
# ----> 6 ckpt = torch.load('results/checkpoints/qat_finetuned.pt', map_location='cpu')
#       7 print("Keys in checkpoint:")
#       8 for k in ckpt.keys():
#
# File ~/venvs/fusion_qat/lib/python3.12/site-packages/torch/serialization.py:1425, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1422 if "encoding" not in pickle_load_args.keys():
#    1423     pickle_load_args["encoding"] = "utf-8"
# -> 1425 with _open_file_like(f, "rb") as opened_file:
#    1426     if _is_zipfile(opened_file):
#    1427         # The zipfile reader is going to advance the current file position.
#    1428         # If we want to actually tail call to torch.jit.load, we need to
# ...
